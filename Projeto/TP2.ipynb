# %% [markdown]
# # Teoria de Números Computacional 21/22
# ___
# ## Trabalho Prático 2
#
# Grupo:
#
# * Ivo Miguel Gomes Lima (A90214)
#
# * Tiago dos Santos Silva Peixoto Carriço (A91695)
#
#
# ## Contextualização
#
# Para o segundo trabalho prático foi-nos pedido a implementação e explicação do [Algoritmo de *Shanks*](https://en.wikipedia.org/wiki/Baby-step_giant-step), baby-step giant-step, que permite resolver o Problema do Logaritmo Discreto, tendo em vista o caso de uma raiz primitiva r de $Z_p^*$.
#
# Tal como no primeiro trabalho prátrico foi necessário o uso do [SageMath](https://www.sagemath.org) e a consulta da secção 3.6.2 (Cap 3) do ${Handbook\ of\ Applied\ Cryptography,\ A.\ Menezes,\ P.\ van\ Oorschot,\ S.\ Vanstone,\ CRC\ Press,\ 1996}$ disponibilizado pelo docente da cadeira.
#
# ### Problema do Logaritmo Discreto
#
# Existem muitos sistemas de criptografia cuja segurança é baseada na dificuldade em resolver logaritmos discretos.
# Algebricamente, o logaritmo é um expoente. Mais precisamente, se $1 \neq b > 0 $ é um número real, então para valores positivos de $a \in \R$, o logaritmo de $a$ na base $b$ deve ser elevado para produzir $a$.
#
# Neste trabalho abordaremos um algoritmo para grupos arbitrários, isto é, aqueles que não exploram qualquer propriedade específica do grupo. Para tal apresentaremos um algoritmo característico denominado Algoritmo de $Shanks$.
#
#
# ### Criação do Algoritmo de *Shanks*
#
# [Daniel Shanks](https://en.wikipedia.org/wiki/Daniel_Shanks) desenvolveu em 1973 um método eficiente para calcular logaritmos discretos. Para este algoritmo necessitamos de enumerar os elementos de $G$.
#
# Tomando $G$ como grupo e $\alpha \in G$ um elemento de ordem finita. Dado $\beta \in \langle b \rangle$, existe um único natural $x$, $0 \leq x \leq |\langle b \rangle|-1$ tal que $a=b^{x}$, portanto, o logaritmo discreto de $a$ na base $b$ é bem definido.
#
# Seja $n\in \N$, $n \geq | \langle b \rangle|$ e $m =\lceil \sqrt{n} \rceil$
# Dado $\beta \in G$, vamos calcular o logaritmo discreto isto é $x=log_{\alpha}\beta$.
#
# Tomando as hipóteses acima, concluímos que para a elaboração do código devemos:
#
# Calcular o $m =\lceil \sqrt{n} \rceil$, de seguida fazemos a construção de pares ordenados $(j,\alpha ^{j})$, com $0 \leq j < m$ que serão inseridos numa tabela de $Hash$ por forma a otimizar a pesquisa.
#
# Após essa construção computamos $\alpha ^ {-m}$.
#
# Por fim procuramos entre os pares aquele em que a segunda coordenada é igual a $\beta \times (\alpha ^ {-m}) ^ i$ que caso apareça implica o calculo de $i \times m + j $, que é a solução de $x \equiv \log_{\alpha}\beta \mod n$.
#
# Podemos então concluir que o Algoritmo de $Shanks$ é determinístico, tendo um tempo de execução de $O(\sqrt{n})$.

# %%
def shanks(a, b, n, p):
    Zn = IntegerModRing(p)
    m = ceil(sqrt(n))
    
    tabela = {}
    j = 0
    while j < m:
        tabela[Zn(a ^ j)] = j
        j += 1
    
    a_e_m = Zn(a ^ -m)
    
    for i in range(m):
        y = Zn(b * a_e_m^i)
        if y in tabela:
            j = tabela[y]
            return i * m + j  
    
    return "Não foi  encontrada solução."

# %% [markdown]
# ## Exemplos
#
# ### Exemplo 1
#
# Imaginemos que queremos aplicar o Algoritmo de $baby-step\ giant-step$ em $\mathbb{Z}_{113}^*$ teremos então que $p = 113$, sendo $\alpha = 3$ um gerador desse mesmo grupo cíclico que possuí uma ordem $n=112$. Considerando $\beta = 57$ significa que podemos determinar que o valor de $x \equiv \log_{3} 57$ será:

# %%
a = 3
b = 57
p = 113

Zn = IntegerModRing(p)
n = Zn(a).multiplicative_order()

# %%
x = shanks(a, b, n, p)
x
# Out:
# 100

# %%
a^x % p == b
# Out:
# True

# %% [markdown]
# ### Exemplo 2
#
# Neste segundo exemplo aplicamos o Algoritmo de $Shanks$ com um $p = 53$, que implica um gerador $\alpha=2$, ordem $n=52$ e que tomando um $\beta=45$ fará o valor de $x \equiv log_{2}45 \mod 52$, ser:

# %%
a = 2
b = 45
p = 53

Zn = IntegerModRing(p)
n = Zn(a).multiplicative_order()

# %%
x = shanks(a, b, n, p)
x
# Out:
# 29

# %%
a^x % p == b
# Out:
# True

# %% [markdown]
# ### Exemplo 3
#
# Para este último exemplo queremos usar o Algoritmo em $\mathbb{Z}_{53}^*$, isto é, $p = 53$, tem um gerador $\alpha = 2$ e a sua ordem é $n = 52$. O $\beta = 12$ e queremos calcular o de $x \equiv log_{2} 12 \mod 52$, que é:

# %%
a = 2
b = 12
p = 53

Zn = IntegerModRing(p)
n = Zn(a).multiplicative_order()

# %%
x = shanks(a, b, n, p)
x

# %%
a^x % p == b
